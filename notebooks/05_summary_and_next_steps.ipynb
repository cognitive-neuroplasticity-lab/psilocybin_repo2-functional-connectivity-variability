# %%
# !pip -q install pandas
import pandas as pd

# %%
summary_df = pd.DataFrame({
    "Category": [
        "Repository",
        "Dataset",
        "Subjects Analysed",
        "Imaging Type",
        "Pipeline",
        "Status"
    ],
    "Value": [
        "psilocybin_repo2",
        "ds006072",
        "3",
        "Resting-state fMRI",
        "Single-echo atlas connectivity",
        "Complete"
    ]
})

summary_df
# Out:
#             Category                           Value
# 0         Repository                psilocybin_repo2
# 1            Dataset                        ds006072
# 2  Subjects Analysed                               3
# 3       Imaging Type              Resting-state fMRI
# 4           Pipeline  Single-echo atlas connectivity
# 5             Status                        Complete

# %%
findings = [
    "Subject-level functional connectivity matrices were successfully constructed.",
    "Cross-subject mean connectivity differed across participants.",
    "Connectivity profile similarity was low, indicating heterogeneity.",
    "A shared matrix dimension enabled standardized comparison.",
    "The dataset supports scalable individual-differences analyses."
]

for f in findings:
    print("-", f)
# Out:
# - Subject-level functional connectivity matrices were successfully constructed.
# - Cross-subject mean connectivity differed across participants.
# - Connectivity profile similarity was low, indicating heterogeneity.
# - A shared matrix dimension enabled standardized comparison.
# - The dataset supports scalable individual-differences analyses.

# %%
decisions = [
    "Initial full multi-echo plan was revised after file-size inspection.",
    "Pipeline pivoted to a feasible single-echo strategy.",
    "Raw files were processed sequentially to manage storage.",
    "Cross-subject matrices were harmonized via common dimensions."
]

for d in decisions:
    print("-", d)
# Out:
# - Initial full multi-echo plan was revised after file-size inspection.
# - Pipeline pivoted to a feasible single-echo strategy.
# - Raw files were processed sequentially to manage storage.
# - Cross-subject matrices were harmonized via common dimensions.

# %%
limitations = [
    "Current analysis used three subjects for proof-of-concept.",
    "Only one session/run was analysed per subject.",
    "Single-echo processing is pragmatic but not full multi-echo integration.",
    "Connectivity was summarized at atlas level only."
]

for l in limitations:
    print("-", l)
# Out:
# - Current analysis used three subjects for proof-of-concept.
# - Only one session/run was analysed per subject.
# - Single-echo processing is pragmatic but not full multi-echo integration.
# - Connectivity was summarized at atlas level only.

# %%
next_df = pd.DataFrame({
    "Next Step": [
        "Expand to all subjects",
        "Add multiple sessions",
        "Compare acute vs follow-up scans",
        "Relate connectivity to cognition",
        "Test reproducibility choices"
    ],
    "Future Repository": [
        "psilocybin_repo2",
        "psilocybin_repo2",
        "psilocybin_repo3",
        "psilocybin_repo4",
        "psilocybin_repo5"
    ]
})

next_df
# Out:
#                           Next Step Future Repository
# 0            Expand to all subjects  psilocybin_repo2
# 1             Add multiple sessions  psilocybin_repo2
# 2  Compare acute vs follow-up scans  psilocybin_repo3
# 3  Relate connectivity to cognition  psilocybin_repo4
# 4      Test reproducibility choices  psilocybin_repo5

# %%
print("Notebook 5 complete.")
print("Repo 2 establishes real evidence for inter-individual connectivity variability.")
# Out:
# Notebook 5 complete.
# Repo 2 establishes real evidence for inter-individual connectivity variability.
